# %%
pip install tensorflow

# %%
import tensorflow as tf

# Define the input size
input_size = 10  # For example, if you're working with MNIST dataset

# Define the architecture of the neural network
hidden_layer_sizes = [8, 1]  # Two hidden layers with 256 and 128 neurons respectively
output_size = 4  # For example, if you're working with MNIST (4 classes)

# Initialize the input placeholder
inputs = tf.keras.layers.Input(shape=(input_size,))

# Create hidden layers
x = inputs
for size in hidden_layer_sizes:
    x = tf.keras.layers.Dense(size, activation='relu')(x)

# Create output layer
outputs = tf.keras.layers.Dense(output_size, activation='softmax')(x)

# Create the model
model = tf.keras.Model(inputs=inputs, outputs=outputs)

# Print model summary
model.summary()

# Calculate the total number of parameters
total_parameters = model.count_params()
print("Total parameters:", total_parameters)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 10)]              0
#
#  dense_12 (Dense)            (None, 8)                 88
#
#  dense_13 (Dense)            (None, 1)                 9
#
#  dense_14 (Dense)            (None, 4)                 8
#
# ...
# Total params: 105 (420.00 Byte)
# Trainable params: 105 (420.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Total parameters: 105

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_diabetes
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load the diabetes dataset
diabetes = load_diabetes()
X, y = diabetes.data, diabetes.target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build the ANN model
model = Sequential([
    Dense(25, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(15, activation='relu'),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=10, verbose=1)

# Evaluate the model on the test set
loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')

# Predict on test set
predictions = model.predict(X_test)
# Out:
# Epoch 1/50
# 36/36 [==============================] - 1s 3ms/step - loss: 28977.5977
# Epoch 2/50
# 36/36 [==============================] - 0s 3ms/step - loss: 28473.7812
# Epoch 3/50
# 36/36 [==============================] - 0s 2ms/step - loss: 27546.3223
# Epoch 4/50
# 36/36 [==============================] - 0s 2ms/step - loss: 25929.0820
# Epoch 5/50
# 36/36 [==============================] - 0s 2ms/step - loss: 23461.5234
# Epoch 6/50
# 36/36 [==============================] - 0s 2ms/step - loss: 20042.4336
# Epoch 7/50
# 36/36 [==============================] - 0s 2ms/step - loss: 16037.6074
# Epoch 8/50
# 36/36 [==============================] - 0s 2ms/step - loss: 12007.6543
# Epoch 9/50
# 36/36 [==============================] - 0s 2ms/step - loss: 8842.6143
# Epoch 10/50
# 36/36 [==============================] - 0s 2ms/step - loss: 6883.5430
# Epoch 11/50
# 36/36 [==============================] - 0s 2ms/step - loss: 5772.9907
# Epoch 12/50
# ...
